# %%
import numpy as np
import healpy as hp

# %%
path = '/global/cfs/cdirs/sobs/sims/scan-s0001/h_n_maps/'

# %%
ls /global/cfs/cdirs/sobs/sims/scan-s0001/h_n_maps | grep high_cadence_constant_scan_3
# Out:
# high_cadence_constant_scan_3_el_w13_p000_f150_A_cos_1.fits
# high_cadence_constant_scan_3_el_w13_p000_f150_A_cos_2.fits
# high_cadence_constant_scan_3_el_w13_p000_f150_A_cos_3.fits
# high_cadence_constant_scan_3_el_w13_p000_f150_A_cos_4.fits
# high_cadence_constant_scan_3_el_w13_p000_f150_A_sin_1.fits
# high_cadence_constant_scan_3_el_w13_p000_f150_A_sin_2.fits
# high_cadence_constant_scan_3_el_w13_p000_f150_A_sin_3.fits
# high_cadence_constant_scan_3_el_w13_p000_f150_A_sin_4.fits
# high_cadence_constant_scan_3_el_w13_p000_f150_B_cos_1.fits
# high_cadence_constant_scan_3_el_w13_p000_f150_B_cos_2.fits
# high_cadence_constant_scan_3_el_w13_p000_f150_B_cos_3.fits
# high_cadence_constant_scan_3_el_w13_p000_f150_B_cos_4.fits
# high_cadence_constant_scan_3_el_w13_p000_f150_B_sin_1.fits
# high_cadence_constant_scan_3_el_w13_p000_f150_B_sin_2.fits
# high_cadence_constant_scan_3_el_w13_p000_f150_B_sin_3.fits
# high_cadence_constant_scan_3_el_w13_p000_f150_B_sin_4.fits
# ...

# %%
for i in range(1, 4):
    test_h_n = hp.read_map(path + f'high_cadence_constant_scan_3_el_w13_p000_f150_A_cos_{i}.fits', field=None)
    hp.mollview(test_h_n)
